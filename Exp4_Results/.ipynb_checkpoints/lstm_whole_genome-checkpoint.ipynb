# %%
# imports
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

np.random.seed(7)

import tensorflow as tf
from tensorflow.keras import layers, callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import os
os.getcwd()
os.chdir("../")
# %pwd
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Masters_thesis'

# %%
FILE_DIR = "artifacts"
FILE_PATH = "nsp1,3,5,8,9,13,15_mutation_rate_1e7_rounded_without_duplicates.csv"

# %%
data = pd.read_csv(os.path.join(FILE_DIR, FILE_PATH))
data.tail()
# Out:
#         AC   AT   AG   CA       CT   CG   TA       TC   TG   GA   GC       GT
# 80220  0.0  0.0  0.0  0.0  6.75790  0.0  0.0  1.12632  0.0  0.0  0.0  1.12632
# 80221  0.0  0.0  0.0  0.0  6.75790  0.0  0.0  0.00000  0.0  0.0  0.0  1.12632
# 80222  0.0  0.0  0.0  0.0  5.63158  0.0  0.0  0.00000  0.0  0.0  0.0  1.12632
# 80223  0.0  0.0  0.0  0.0  4.50527  0.0  0.0  1.12632  0.0  0.0  0.0  2.25263
# 80224  0.0  0.0  0.0  0.0  5.63158  0.0  0.0  2.25263  0.0  0.0  0.0  1.12632

# %%
dataset = data.values
dataset = dataset.astype('float32')

print('Dataset Shape: ', np.shape(dataset))
# Out:
# Dataset Shape:  (80225, 12)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)


train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 64180 16045

# %%
def create_dataset(dataset, look_back, btch): 
    dataX, dataY = [], []
    z=0
    inc=1
    for i in range(0,len(dataset)-look_back,inc):
        a = dataset[i:(i+look_back)]
        
        dataX.append(np.reshape(a,(btch,12)))
        dataY.append(dataset[i+look_back])
#         print(a,dataY)
        z+=1
    return np.array(dataX), np.array(dataY)
 
btch=12    
look_back = 12
trainX, trainY = create_dataset(train, look_back, btch)
testX, testY = create_dataset(test, look_back, btch)

trainX = np.reshape(trainX, (trainX.shape[0], btch,12))
testX = np.reshape(testX, (testX.shape[0], btch, 12))
print(len(trainX), len(testX))
# Out:
# 64168 16033

# %% [markdown]
# # LSTM

# %%
model = tf.keras.Sequential()
model.add(layers.LSTM(500,activation='relu', input_shape=(btch, 12))) 

model.add(layers.Dense(250))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(50))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(12)) #softmax

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001))

# Train the model with the ModelCheckpoint callback
history = model.fit(trainX, trainY, validation_split=0.30, epochs=200, batch_size=256, verbose=2)

# Find the minimum validation loss and its respective training loss and epoch
min_val_loss = min(history.history['val_loss'])
min_val_loss_epoch = history.history['val_loss'].index(min_val_loss)
train_loss_at_min_val_loss = history.history['loss'][min_val_loss_epoch]

# Print the results
print(f"Minimum Validation Loss: {min_val_loss} at Epoch {min_val_loss_epoch}")
print(f"Training Loss at Minimum Validation Loss: {train_loss_at_min_val_loss}")
# Out:
# Epoch 1/200
# 176/176 - 46s - loss: 0.0158 - val_loss: 0.0127 - 46s/epoch - 262ms/step
# Epoch 2/200
# 176/176 - 44s - loss: 0.0119 - val_loss: 0.0084 - 44s/epoch - 250ms/step
# Epoch 3/200
# 176/176 - 46s - loss: 0.0109 - val_loss: 0.0078 - 46s/epoch - 259ms/step
# Epoch 4/200
# 176/176 - 43s - loss: 0.0105 - val_loss: 0.0075 - 43s/epoch - 246ms/step
# Epoch 5/200
# 176/176 - 42s - loss: 0.0103 - val_loss: 0.0072 - 42s/epoch - 239ms/step
# Epoch 6/200
# 176/176 - 43s - loss: 0.0100 - val_loss: 0.0070 - 43s/epoch - 243ms/step
# Epoch 7/200
# 176/176 - 44s - loss: 0.0098 - val_loss: 0.0069 - 44s/epoch - 252ms/step
# Epoch 8/200
# 176/176 - 44s - loss: 0.0096 - val_loss: 0.0067 - 44s/epoch - 253ms/step
# Epoch 9/200
# 176/176 - 45s - loss: 0.0094 - val_loss: 0.0066 - 45s/epoch - 256ms/step
# Epoch 10/200
# 176/176 - 44s - loss: 0.0092 - val_loss: 0.0064 - 44s/epoch - 252ms/step
# Epoch 11/200
# 176/176 - 43s - loss: 0.0091 - val_loss: 0.0063 - 43s/epoch - 243ms/step
# Epoch 12/200
# 176/176 - 42s - loss: 0.0089 - val_loss: 0.0062 - 42s/epoch - 241ms/step
# Epoch 13/200
# 176/176 - 43s - loss: 0.0088 - val_loss: 0.0060 - 43s/epoch - 242ms/step
# Epoch 14/200
# 176/176 - 44s - loss: 0.0086 - val_loss: 0.0059 - 44s/epoch - 248ms/step
# Epoch 15/200
# 176/176 - 42s - loss: 0.0085 - val_loss: 0.0059 - 42s/epoch - 241ms/step
# Epoch 16/200
# 176/176 - 43s - loss: 0.0084 - val_loss: 0.0058 - 43s/epoch - 243ms/step
# Epoch 17/200
# 176/176 - 43s - loss: 0.0083 - val_loss: 0.0057 - 43s/epoch - 245ms/step
# Epoch 18/200
# 176/176 - 43s - loss: 0.0082 - val_loss: 0.0056 - 43s/epoch - 244ms/step
# Epoch 19/200
# 176/176 - 43s - loss: 0.0080 - val_loss: 0.0056 - 43s/epoch - 245ms/step
# Epoch 20/200
# 176/176 - 44s - loss: 0.0080 - val_loss: 0.0054 - 44s/epoch - 249ms/step
# Epoch 21/200
# 176/176 - 43s - loss: 0.0079 - val_loss: 0.0054 - 43s/epoch - 246ms/step
# Epoch 22/200
# 176/176 - 43s - loss: 0.0078 - val_loss: 0.0053 - 43s/epoch - 244ms/step
# Epoch 23/200
# 176/176 - 43s - loss: 0.0077 - val_loss: 0.0053 - 43s/epoch - 244ms/step
# Epoch 24/200
# 176/176 - 42s - loss: 0.0076 - val_loss: 0.0053 - 42s/epoch - 240ms/step
# Epoch 25/200
# 176/176 - 43s - loss: 0.0075 - val_loss: 0.0052 - 43s/epoch - 246ms/step
# Epoch 26/200
# 176/176 - 43s - loss: 0.0074 - val_loss: 0.0052 - 43s/epoch - 243ms/step
# Epoch 27/200
# 176/176 - 43s - loss: 0.0073 - val_loss: 0.0052 - 43s/epoch - 243ms/step
# Epoch 28/200
# 176/176 - 44s - loss: 0.0073 - val_loss: 0.0051 - 44s/epoch - 250ms/step
# Epoch 29/200
# 176/176 - 43s - loss: 0.0072 - val_loss: 0.0050 - 43s/epoch - 246ms/step
# Epoch 30/200
# 176/176 - 42s - loss: 0.0071 - val_loss: 0.0049 - 42s/epoch - 241ms/step
# Epoch 31/200
# 176/176 - 43s - loss: 0.0070 - val_loss: 0.0050 - 43s/epoch - 246ms/step
# Epoch 32/200
# 176/176 - 43s - loss: 0.0070 - val_loss: 0.0048 - 43s/epoch - 244ms/step
# Epoch 33/200
# 176/176 - 42s - loss: 0.0069 - val_loss: 0.0049 - 42s/epoch - 241ms/step
# Epoch 34/200
# 176/176 - 43s - loss: 0.0069 - val_loss: 0.0048 - 43s/epoch - 242ms/step
# Epoch 35/200
# 176/176 - 44s - loss: 0.0068 - val_loss: 0.0049 - 44s/epoch - 247ms/step
# Epoch 36/200
# 176/176 - 44s - loss: 0.0067 - val_loss: 0.0049 - 44s/epoch - 248ms/step
# Epoch 37/200
# 176/176 - 44s - loss: 0.0067 - val_loss: 0.0048 - 44s/epoch - 251ms/step
# Epoch 38/200
# 176/176 - 44s - loss: 0.0067 - val_loss: 0.0047 - 44s/epoch - 251ms/step
# Epoch 39/200
# 176/176 - 43s - loss: 0.0066 - val_loss: 0.0046 - 43s/epoch - 246ms/step
# Epoch 40/200
# 176/176 - 44s - loss: 0.0065 - val_loss: 0.0047 - 44s/epoch - 250ms/step
# Epoch 41/200
# 176/176 - 46s - loss: 0.0065 - val_loss: 0.0046 - 46s/epoch - 262ms/step
# Epoch 42/200
# 176/176 - 44s - loss: 0.0064 - val_loss: 0.0046 - 44s/epoch - 249ms/step
# Epoch 43/200
# 176/176 - 42s - loss: 0.0064 - val_loss: 0.0046 - 42s/epoch - 241ms/step
# Epoch 44/200
# 176/176 - 43s - loss: 0.0063 - val_loss: 0.0046 - 43s/epoch - 244ms/step
# Epoch 45/200
# 176/176 - 43s - loss: 0.0063 - val_loss: 0.0046 - 43s/epoch - 242ms/step
# Epoch 46/200
# 176/176 - 44s - loss: 0.0063 - val_loss: 0.0046 - 44s/epoch - 247ms/step
# Epoch 47/200
# 176/176 - 44s - loss: 0.0062 - val_loss: 0.0045 - 44s/epoch - 249ms/step
# Epoch 48/200
# 176/176 - 43s - loss: 0.0062 - val_loss: 0.0045 - 43s/epoch - 243ms/step
# Epoch 49/200
# 176/176 - 44s - loss: 0.0062 - val_loss: 0.0045 - 44s/epoch - 248ms/step
# Epoch 50/200
# 176/176 - 45s - loss: 0.0061 - val_loss: 0.0045 - 45s/epoch - 256ms/step
# Epoch 51/200
# 176/176 - 44s - loss: 0.0061 - val_loss: 0.0044 - 44s/epoch - 249ms/step
# Epoch 52/200
# 176/176 - 44s - loss: 0.0061 - val_loss: 0.0044 - 44s/epoch - 248ms/step
# Epoch 53/200
# 176/176 - 43s - loss: 0.0060 - val_loss: 0.0044 - 43s/epoch - 245ms/step
# Epoch 54/200
# 176/176 - 40s - loss: 0.0060 - val_loss: 0.0044 - 40s/epoch - 230ms/step
# Epoch 55/200
# 176/176 - 40s - loss: 0.0060 - val_loss: 0.0044 - 40s/epoch - 228ms/step
# Epoch 56/200
# 176/176 - 42s - loss: 0.0059 - val_loss: 0.0044 - 42s/epoch - 240ms/step
# Epoch 57/200
# 176/176 - 41s - loss: 0.0059 - val_loss: 0.0044 - 41s/epoch - 232ms/step
# Epoch 58/200
# 176/176 - 40s - loss: 0.0059 - val_loss: 0.0044 - 40s/epoch - 229ms/step
# Epoch 59/200
# 176/176 - 40s - loss: 0.0058 - val_loss: 0.0043 - 40s/epoch - 229ms/step
# Epoch 60/200
# 176/176 - 41s - loss: 0.0058 - val_loss: 0.0043 - 41s/epoch - 232ms/step
# Epoch 61/200
# 176/176 - 41s - loss: 0.0058 - val_loss: 0.0043 - 41s/epoch - 230ms/step
# Epoch 62/200
# 176/176 - 41s - loss: 0.0058 - val_loss: 0.0043 - 41s/epoch - 232ms/step
# Epoch 63/200
# 176/176 - 41s - loss: 0.0057 - val_loss: 0.0043 - 41s/epoch - 230ms/step
# Epoch 64/200
# 176/176 - 40s - loss: 0.0057 - val_loss: 0.0043 - 40s/epoch - 230ms/step
# Epoch 65/200
# 176/176 - 40s - loss: 0.0057 - val_loss: 0.0043 - 40s/epoch - 228ms/step
# Epoch 66/200
# 176/176 - 40s - loss: 0.0057 - val_loss: 0.0043 - 40s/epoch - 229ms/step
# Epoch 67/200
# 176/176 - 43s - loss: 0.0057 - val_loss: 0.0043 - 43s/epoch - 246ms/step
# Epoch 68/200
# 176/176 - 44s - loss: 0.0056 - val_loss: 0.0043 - 44s/epoch - 247ms/step
# Epoch 69/200
# 176/176 - 41s - loss: 0.0056 - val_loss: 0.0043 - 41s/epoch - 233ms/step
# Epoch 70/200
# 176/176 - 41s - loss: 0.0056 - val_loss: 0.0042 - 41s/epoch - 230ms/step
# Epoch 71/200
# 176/176 - 41s - loss: 0.0056 - val_loss: 0.0042 - 41s/epoch - 232ms/step
# Epoch 72/200
# 176/176 - 41s - loss: 0.0056 - val_loss: 0.0042 - 41s/epoch - 236ms/step
# Epoch 73/200
# 176/176 - 42s - loss: 0.0055 - val_loss: 0.0042 - 42s/epoch - 239ms/step
# Epoch 74/200
# 176/176 - 45s - loss: 0.0055 - val_loss: 0.0042 - 45s/epoch - 254ms/step
# Epoch 75/200
# 176/176 - 44s - loss: 0.0055 - val_loss: 0.0042 - 44s/epoch - 249ms/step
# Epoch 76/200
# 176/176 - 42s - loss: 0.0055 - val_loss: 0.0042 - 42s/epoch - 239ms/step
# Epoch 77/200
# 176/176 - 40s - loss: 0.0055 - val_loss: 0.0042 - 40s/epoch - 228ms/step
# Epoch 78/200
# 176/176 - 40s - loss: 0.0055 - val_loss: 0.0042 - 40s/epoch - 229ms/step
# Epoch 79/200
# Epoch 130/200
# 176/176 - 49s - loss: 0.0050 - val_loss: 0.0041 - 49s/epoch - 276ms/step
# Epoch 131/200
# 176/176 - 49s - loss: 0.0050 - val_loss: 0.0041 - 49s/epoch - 281ms/step
# Epoch 132/200
# 176/176 - 49s - loss: 0.0050 - val_loss: 0.0041 - 49s/epoch - 279ms/step
# Epoch 133/200
# 176/176 - 286s - loss: 0.0050 - val_loss: 0.0041 - 286s/epoch - 2s/step
# Epoch 134/200
# 176/176 - 49s - loss: 0.0050 - val_loss: 0.0041 - 49s/epoch - 279ms/step
# Epoch 135/200
# 176/176 - 50s - loss: 0.0050 - val_loss: 0.0041 - 50s/epoch - 285ms/step
# Epoch 136/200
# 176/176 - 51s - loss: 0.0050 - val_loss: 0.0041 - 51s/epoch - 290ms/step
# Epoch 137/200
# 176/176 - 51s - loss: 0.0050 - val_loss: 0.0041 - 51s/epoch - 291ms/step
# Epoch 138/200
# 176/176 - 52s - loss: 0.0050 - val_loss: 0.0041 - 52s/epoch - 295ms/step
# Epoch 139/200
# 176/176 - 50s - loss: 0.0050 - val_loss: 0.0041 - 50s/epoch - 282ms/step
# Epoch 140/200
# 176/176 - 52s - loss: 0.0050 - val_loss: 0.0041 - 52s/epoch - 297ms/step
# Epoch 141/200
# 176/176 - 52s - loss: 0.0050 - val_loss: 0.0041 - 52s/epoch - 293ms/step
# Epoch 142/200
# 176/176 - 51s - loss: 0.0050 - val_loss: 0.0041 - 51s/epoch - 288ms/step
# Epoch 143/200
# 176/176 - 51s - loss: 0.0050 - val_loss: 0.0041 - 51s/epoch - 289ms/step
# Epoch 144/200
# 176/176 - 50s - loss: 0.0050 - val_loss: 0.0041 - 50s/epoch - 281ms/step
# Epoch 145/200
# 176/176 - 50s - loss: 0.0050 - val_loss: 0.0041 - 50s/epoch - 286ms/step
# Epoch 146/200
# 176/176 - 53s - loss: 0.0050 - val_loss: 0.0041 - 53s/epoch - 302ms/step
# Epoch 147/200
# 176/176 - 52s - loss: 0.0050 - val_loss: 0.0041 - 52s/epoch - 293ms/step
# Epoch 148/200
# 176/176 - 45s - loss: 0.0050 - val_loss: 0.0041 - 45s/epoch - 254ms/step
# Epoch 149/200
# 176/176 - 49s - loss: 0.0050 - val_loss: 0.0041 - 49s/epoch - 280ms/step
# Epoch 150/200
# 176/176 - 46s - loss: 0.0050 - val_loss: 0.0041 - 46s/epoch - 262ms/step
# Epoch 151/200
# 176/176 - 43s - loss: 0.0050 - val_loss: 0.0041 - 43s/epoch - 246ms/step
# Epoch 152/200
# 176/176 - 44s - loss: 0.0050 - val_loss: 0.0041 - 44s/epoch - 252ms/step
# Epoch 153/200
# 176/176 - 43s - loss: 0.0050 - val_loss: 0.0041 - 43s/epoch - 242ms/step
# Epoch 154/200
# 176/176 - 50s - loss: 0.0050 - val_loss: 0.0040 - 50s/epoch - 284ms/step
# Epoch 155/200
# 176/176 - 46s - loss: 0.0050 - val_loss: 0.0041 - 46s/epoch - 261ms/step
# Epoch 156/200
# 176/176 - 43s - loss: 0.0050 - val_loss: 0.0040 - 43s/epoch - 247ms/step
# Epoch 157/200
# 176/176 - 43s - loss: 0.0050 - val_loss: 0.0041 - 43s/epoch - 242ms/step
# Epoch 158/200
# 176/176 - 42s - loss: 0.0050 - val_loss: 0.0041 - 42s/epoch - 241ms/step
# Epoch 159/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0041 - 43s/epoch - 246ms/step
# Epoch 160/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 244ms/step
# Epoch 161/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 247ms/step
# Epoch 162/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0040 - 42s/epoch - 241ms/step
# Epoch 163/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0041 - 44s/epoch - 248ms/step
# Epoch 164/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0040 - 42s/epoch - 239ms/step
# Epoch 165/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0040 - 42s/epoch - 241ms/step
# Epoch 166/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0040 - 42s/epoch - 241ms/step
# Epoch 167/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0040 - 44s/epoch - 248ms/step
# Epoch 168/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0041 - 42s/epoch - 241ms/step
# Epoch 169/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0041 - 42s/epoch - 240ms/step
# Epoch 170/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0041 - 42s/epoch - 241ms/step
# Epoch 171/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0041 - 44s/epoch - 251ms/step
# Epoch 172/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0041 - 44s/epoch - 249ms/step
# Epoch 173/200
# 176/176 - 47s - loss: 0.0049 - val_loss: 0.0041 - 47s/epoch - 268ms/step
# Epoch 174/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0041 - 44s/epoch - 250ms/step
# Epoch 175/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0041 - 42s/epoch - 240ms/step
# Epoch 176/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0041 - 42s/epoch - 241ms/step
# Epoch 177/200
# 176/176 - 42s - loss: 0.0049 - val_loss: 0.0040 - 42s/epoch - 241ms/step
# Epoch 178/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 244ms/step
# Epoch 179/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0040 - 44s/epoch - 251ms/step
# Epoch 180/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0041 - 43s/epoch - 244ms/step
# Epoch 181/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0041 - 44s/epoch - 251ms/step
# Epoch 182/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 246ms/step
# Epoch 183/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 245ms/step
# Epoch 184/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 245ms/step
# Epoch 185/200
# 176/176 - 44s - loss: 0.0049 - val_loss: 0.0040 - 44s/epoch - 249ms/step
# Epoch 186/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 244ms/step
# Epoch 187/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0040 - 41s/epoch - 233ms/step
# Epoch 188/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0040 - 41s/epoch - 231ms/step
# Epoch 189/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0041 - 41s/epoch - 231ms/step
# Epoch 190/200
# 176/176 - 40s - loss: 0.0049 - val_loss: 0.0041 - 40s/epoch - 229ms/step
# Epoch 191/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 244ms/step
# Epoch 192/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0041 - 41s/epoch - 234ms/step
# Epoch 193/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0040 - 41s/epoch - 234ms/step
# Epoch 194/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0041 - 43s/epoch - 244ms/step
# Epoch 195/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0040 - 41s/epoch - 233ms/step
# Epoch 196/200
# 176/176 - 41s - loss: 0.0049 - val_loss: 0.0040 - 41s/epoch - 233ms/step
# Epoch 197/200
# 176/176 - 40s - loss: 0.0049 - val_loss: 0.0040 - 40s/epoch - 225ms/step
# Epoch 198/200
# 176/176 - 40s - loss: 0.0049 - val_loss: 0.0040 - 40s/epoch - 230ms/step
# Epoch 199/200
# 176/176 - 43s - loss: 0.0049 - val_loss: 0.0040 - 43s/epoch - 245ms/step
# Epoch 200/200
# 176/176 - 45s - loss: 0.0049 - val_loss: 0.0041 - 45s/epoch - 257ms/step
# Minimum Validation Loss: 0.0040198625065386295 at Epoch 181
# Training Loss at Minimum Validation Loss: 0.004915168043226004

# %%
# %pwd
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Masters_thesis'

# %%
FOLDER_DIR = "C:\\Users\\Lenovo\\Documents\\Masters_thesis\\notebooks_7proteins\\"
FOLDER_DIR
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Masters_thesis\\notebooks_7proteins\\'

# %%
plt.plot(history.history['loss'])
plt.plot(np.array(history.history['val_loss']))
plt.title('Model loss')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig(os.path.join(FOLDER_DIR, "plots", 'lstm_model_loss_plot.png'), dpi=400)
plt.show()

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)


# invert predictions

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY)
# Out:
# 2006/2006 [==============================] - 65s 32ms/step
# 502/502 [==============================] - 16s 31ms/step

# %%
#calculating error

trainScore_rmse = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train RMSE: %.2f RMSE' % (trainScore_rmse))
testScore_rmse = math.sqrt(mean_squared_error(testY, testPredict))
print('Test RMSE: %.2f RMSE' % (testScore_rmse))

trainScore_mae = mean_absolute_error(trainY, trainPredict)
print('Train MAE: %.2f MAE' % (trainScore_mae))
testScore_mae = mean_absolute_error(testY, testPredict)
print('Test MAE: %.2f MAE' % (trainScore_mae))

trainScore_mse = mean_squared_error(trainY, trainPredict)
print('Train MSE: %.2f MSE' % (trainScore_mse))
testScore_mse = mean_squared_error(testY, testPredict)
print('Test MSE: %.2f MSE' % (trainScore_mse))
# Out:
# Train RMSE: 0.58 RMSE
# Test RMSE: 0.69 RMSE
# Train MAE: 0.29 MAE
# Test MAE: 0.29 MAE
# Train MSE: 0.34 MSE
# Test MSE: 0.34 MSE

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 500)               1026000
#
#  dense_3 (Dense)             (None, 250)               125250
#
#  activation_2 (Activation)   (None, 250)               0
#
#  dropout_2 (Dropout)         (None, 250)               0
#
#  dense_4 (Dense)             (None, 50)                12550
#
#  activation_3 (Activation)   (None, 50)                0
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_5 (Dense)             (None, 12)                612
#
# =================================================================
# Total params: 1164412 (4.44 MB)
# Trainable params: 1164412 (4.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# FOLDER_DIR = "notebooks_nsp1,3,5,8,9,13,15"
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file=os.path.join(FOLDER_DIR, "models", "model_plot_lstm.png"), 
#            show_shapes=True, show_layer_names=False, dpi='600')
