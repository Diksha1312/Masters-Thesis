# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'E:\\Masters_thesis'

# %%
import pandas as pd
import yaml

# %%
yaml_file_path = "config.yaml"

with open(yaml_file_path, "r") as file:
    config_data = yaml.safe_load(file)
    
print(config_data['nsp1_config']['LENGTH'])
print(config_data['nsp1_config']['PATH'])
print(config_data['ROOT']['DATA_FOLDER'])
print(config_data['ROOT']['DATA_DIR'])
# Out:
# 540
# NSP1_ger_all_nuc_seqs.csv
# data
# raw data

# %% [markdown]
# # clean the raw data in following way:
#
# 1. For each individual protein, keep sequences of its particular length and discard all the other variant length sequences
# 2. Look for sequencing errors like presence of N or D or various other alphabets other than A, T, G, and C
# 3. Merge the sequences using meta data

# %% [markdown]
# # Step 1:
#
# ##    - Iterate over each individual protein.
# ##    - For each protein, keep only the sequences with a particular length.
# ##    - Discard all variant length sequences associated with the protein.
# ##    - Repeat this process for each protein in your dataset.

# %%
### The below code iterates through all proteins and provides the number of rows that have sequence length mismatch

DATA_FOLDER = config_data['ROOT']['DATA_FOLDER']
DATA_DIR = config_data['ROOT']['DATA_DIR']
NEW_DIR = "step1_filtered"
for protein_key, protein_config in config_data.items():

    if protein_key == "ROOT":
        continue
    
    protein_name = protein_key.replace('_config', '')
    protein_csv_path = protein_config['PATH']
    protein_length = protein_config['LENGTH']
    
    df = pd.read_csv(os.path.join(DATA_FOLDER, DATA_DIR, protein_csv_path))
    
    length_condition = df['Sequence'].apply(lambda x: len(str(x))) == protein_length
    
    filtered_df = df[length_condition]
    
    print(f"NSP: {protein_name}")
    print(f"------ Original number of rows: {len(df)}")
    print(f"------ After Preprocessing: {len(filtered_df)}")
    print(f"------ Length of each sequence: {protein_length}")
    print(f"------ Total rows discarded: {len(df) - len(filtered_df)}")
    
    
    # Save the filtered DataFrame to a new CSV file
    os.makedirs(os.path.join(DATA_FOLDER, NEW_DIR), exist_ok=True)
    
    output_csv_path = os.path.join(DATA_FOLDER, NEW_DIR, f"{protein_name}_step1_filtered.csv")
    filtered_df.to_csv(output_csv_path, index=False)
    print(f"------ Filtered data saved to: {output_csv_path}")
    
    print("*"*100)
    
#     print(protein_key)
#     print(protein_config)
# Out:
# NSP: nsp1
# ------ Original number of rows: 490428
# ------ After Preprocessing: 477904
# ------ Length of each sequence: 540
# ------ Total rows discarded: 12524
# ------ Filtered data saved to: data\step1_filtered\nsp1_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp2
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490152
# ------ Length of each sequence: 1914
# ------ Total rows discarded: 313
# ------ Filtered data saved to: data\step1_filtered\nsp2_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp3
# ------ Original number of rows: 490465
# ------ After Preprocessing: 392462
# ------ Length of each sequence: 5835
# ------ Total rows discarded: 98003
# ------ Filtered data saved to: data\step1_filtered\nsp3_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp4
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490238
# ------ Length of each sequence: 1500
# ------ Total rows discarded: 227
# ------ Filtered data saved to: data\step1_filtered\nsp4_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp5
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490367
# ------ Length of each sequence: 918
# ------ Total rows discarded: 98
# ------ Filtered data saved to: data\step1_filtered\nsp5_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp6
# ------ Original number of rows: 490465
# ------ After Preprocessing: 244310
# ------ Length of each sequence: 870
# ------ Total rows discarded: 246155
# ------ Filtered data saved to: data\step1_filtered\nsp6_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp7
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490460
# ------ Length of each sequence: 249
# ------ Total rows discarded: 5
# ------ Filtered data saved to: data\step1_filtered\nsp7_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp8
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490457
# ------ Length of each sequence: 594
# ------ Total rows discarded: 8
# ------ Filtered data saved to: data\step1_filtered\nsp8_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp9
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490371
# ------ Length of each sequence: 339
# ------ Total rows discarded: 94
# ------ Filtered data saved to: data\step1_filtered\nsp9_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp10
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490451
# ------ Length of each sequence: 417
# ------ Total rows discarded: 14
# ------ Filtered data saved to: data\step1_filtered\nsp10_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp11
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490447
# ------ Length of each sequence: 39
# ------ Total rows discarded: 18
# ------ Filtered data saved to: data\step1_filtered\nsp11_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp12
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490328
# ------ Length of each sequence: 2795
# ------ Total rows discarded: 137
# ------ Filtered data saved to: data\step1_filtered\nsp12_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp13
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490432
# ------ Length of each sequence: 1803
# ------ Total rows discarded: 33
# ------ Filtered data saved to: data\step1_filtered\nsp13_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp14
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490361
# ------ Length of each sequence: 1581
# ------ Total rows discarded: 104
# ------ Filtered data saved to: data\step1_filtered\nsp14_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp15
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490275
# ------ Length of each sequence: 1038
# ------ Total rows discarded: 190
# ------ Filtered data saved to: data\step1_filtered\nsp15_step1_filtered.csv
# ****************************************************************************************************
# NSP: nsp16
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490406
# ------ Length of each sequence: 894
# ------ Total rows discarded: 59
# ------ Filtered data saved to: data\step1_filtered\nsp16_step1_filtered.csv
# ****************************************************************************************************
# NSP: spike
# ------ Original number of rows: 490465
# ------ After Preprocessing: 48306
# ------ Length of each sequence: 3822
# ------ Total rows discarded: 442159
# ------ Filtered data saved to: data\step1_filtered\spike_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns3
# ------ Original number of rows: 490465
# ------ After Preprocessing: 486249
# ------ Length of each sequence: 828
# ------ Total rows discarded: 4216
# ------ Filtered data saved to: data\step1_filtered\ns3_step1_filtered.csv
# ****************************************************************************************************
# NSP: e
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490427
# ------ Length of each sequence: 228
# ------ Total rows discarded: 38
# ------ Filtered data saved to: data\step1_filtered\e_step1_filtered.csv
# ****************************************************************************************************
# NSP: m
# ------ Original number of rows: 490465
# ------ After Preprocessing: 490369
# ------ Length of each sequence: 669
# ------ Total rows discarded: 96
# ------ Filtered data saved to: data\step1_filtered\m_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns6
# ------ Original number of rows: 490465
# ------ After Preprocessing: 489257
# ------ Length of each sequence: 186
# ------ Total rows discarded: 1208
# ------ Filtered data saved to: data\step1_filtered\ns6_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns7a
# ------ Original number of rows: 490461
# ------ After Preprocessing: 485714
# ------ Length of each sequence: 366
# ------ Total rows discarded: 4747
# ------ Filtered data saved to: data\step1_filtered\ns7a_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns7b
# ------ Original number of rows: 490463
# ------ After Preprocessing: 489741
# ------ Length of each sequence: 132
# ------ Total rows discarded: 722
# ------ Filtered data saved to: data\step1_filtered\ns7b_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns8
# ------ Original number of rows: 490464
# ------ After Preprocessing: 288616
# ------ Length of each sequence: 366
# ------ Total rows discarded: 201848
# ------ Filtered data saved to: data\step1_filtered\ns8_step1_filtered.csv
# ****************************************************************************************************
# NSP: n
# ------ Original number of rows: 490464
# ------ After Preprocessing: 350714
# ------ Length of each sequence: 1260
# ------ Total rows discarded: 139750
# ------ Filtered data saved to: data\step1_filtered\n_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns9b
# ------ Original number of rows: 490464
# ------ After Preprocessing: 352662
# ------ Length of each sequence: 294
# ------ Total rows discarded: 137802
# ------ Filtered data saved to: data\step1_filtered\ns9b_step1_filtered.csv
# ****************************************************************************************************
# NSP: ns9c
# ------ Original number of rows: 490461
# ------ After Preprocessing: 489639
# ------ Length of each sequence: 222
# ------ Total rows discarded: 822
# ------ Filtered data saved to: data\step1_filtered\ns9c_step1_filtered.csv
# ****************************************************************************************************

# %% [markdown]
# # Step 2:
# ##  - Check for sequencing errors (N, D, or other non-standard alphabets) in each sequence.

# %%
DATA_FOLDER = config_data['ROOT']['DATA_FOLDER']
STEP1_DIR = "step1_filtered"
NEW_DIR = "step2_filtered"

# %%
valid_alphabets = set('ATGC')

for protein_key, protein_config in config_data.items():

    if protein_key == "ROOT":
        continue
    
    protein_name = protein_key.replace('_config', '')
    protein_csv_path_step1 = os.path.join(DATA_FOLDER, STEP1_DIR, f"{protein_name}_step1_filtered.csv")

    if not os.path.exists(protein_csv_path_step1):
        print(f"Skipping {protein_name} as step1 filtered file doesn't exist.")
        continue
    
    df_step1 = pd.read_csv(protein_csv_path_step1)
    
    # Check for sequencing errors
    alphabet_condition = df_step1['Sequence'].apply(lambda x: set(str(x)).issubset(valid_alphabets))
    final_filtered_df = df_step1[alphabet_condition]
    
    print(f"NSP: {protein_name}")
    print(f"------ Original number of rows: {len(df_step1)}")
    print(f"------ After Sequencing Error Filtering: {len(final_filtered_df)}")
    print(f"------ Total rows discarded due to sequencing errors: {len(df_step1) - len(final_filtered_df)}")
    
    # Save the final filtered DataFrame to a new CSV file in step2_filtered folder
    os.makedirs(os.path.join(DATA_FOLDER, NEW_DIR), exist_ok=True)
    
    output_csv_path = os.path.join(DATA_FOLDER, NEW_DIR, f"{protein_name}_step2_filtered.csv")
    final_filtered_df.to_csv(output_csv_path, index=False)
    print(f"------ Final Filtered data saved to: {output_csv_path}")
    
    print("*"*100)
# Out:
# NSP: nsp1
# ------ Original number of rows: 477904
# ------ After Sequencing Error Filtering: 461110
# ------ Total rows discarded due to sequencing errors: 16794
# ------ Final Filtered data saved to: data\step2_filtered\nsp1_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp2
# ------ Original number of rows: 490152
# ------ After Sequencing Error Filtering: 443016
# ------ Total rows discarded due to sequencing errors: 47136
# ------ Final Filtered data saved to: data\step2_filtered\nsp2_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp3
# ------ Original number of rows: 392462
# ------ After Sequencing Error Filtering: 272730
# ------ Total rows discarded due to sequencing errors: 119732
# ------ Final Filtered data saved to: data\step2_filtered\nsp3_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp4
# ------ Original number of rows: 490238
# ------ After Sequencing Error Filtering: 438193
# ------ Total rows discarded due to sequencing errors: 52045
# ------ Final Filtered data saved to: data\step2_filtered\nsp4_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp5
# ------ Original number of rows: 490367
# ------ After Sequencing Error Filtering: 445466
# ------ Total rows discarded due to sequencing errors: 44901
# ------ Final Filtered data saved to: data\step2_filtered\nsp5_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp6
# ------ Original number of rows: 244310
# ------ After Sequencing Error Filtering: 213967
# ------ Total rows discarded due to sequencing errors: 30343
# ------ Final Filtered data saved to: data\step2_filtered\nsp6_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp7
# ------ Original number of rows: 490460
# ------ After Sequencing Error Filtering: 485713
# ------ Total rows discarded due to sequencing errors: 4747
# ------ Final Filtered data saved to: data\step2_filtered\nsp7_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp8
# ------ Original number of rows: 490457
# ------ After Sequencing Error Filtering: 481473
# ------ Total rows discarded due to sequencing errors: 8984
# ------ Final Filtered data saved to: data\step2_filtered\nsp8_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp9
# ------ Original number of rows: 490371
# ------ After Sequencing Error Filtering: 482632
# ------ Total rows discarded due to sequencing errors: 7739
# ------ Final Filtered data saved to: data\step2_filtered\nsp9_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp10
# ------ Original number of rows: 490451
# ------ After Sequencing Error Filtering: 469646
# ------ Total rows discarded due to sequencing errors: 20805
# ------ Final Filtered data saved to: data\step2_filtered\nsp10_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp11
# ------ Original number of rows: 490447
# ------ After Sequencing Error Filtering: 478291
# ------ Total rows discarded due to sequencing errors: 12156
# ------ Final Filtered data saved to: data\step2_filtered\nsp11_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp12
# ------ Original number of rows: 490328
# ------ After Sequencing Error Filtering: 427206
# ------ Total rows discarded due to sequencing errors: 63122
# ------ Final Filtered data saved to: data\step2_filtered\nsp12_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp13
# ------ Original number of rows: 490432
# ------ After Sequencing Error Filtering: 457233
# ------ Total rows discarded due to sequencing errors: 33199
# ------ Final Filtered data saved to: data\step2_filtered\nsp13_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp14
# ------ Original number of rows: 490361
# ------ After Sequencing Error Filtering: 370260
# ------ Total rows discarded due to sequencing errors: 120101
# ------ Final Filtered data saved to: data\step2_filtered\nsp14_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp15
# ------ Original number of rows: 490275
# ------ After Sequencing Error Filtering: 439975
# ------ Total rows discarded due to sequencing errors: 50300
# ------ Final Filtered data saved to: data\step2_filtered\nsp15_step2_filtered.csv
# ****************************************************************************************************
# NSP: nsp16
# ------ Original number of rows: 490406
# ------ After Sequencing Error Filtering: 448262
# ------ Total rows discarded due to sequencing errors: 42144
# ------ Final Filtered data saved to: data\step2_filtered\nsp16_step2_filtered.csv
# ****************************************************************************************************
# NSP: spike
# ------ Original number of rows: 48306
# ------ After Sequencing Error Filtering: 19610
# ------ Total rows discarded due to sequencing errors: 28696
# ------ Final Filtered data saved to: data\step2_filtered\spike_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns3
# ------ Original number of rows: 486249
# ------ After Sequencing Error Filtering: 420039
# ------ Total rows discarded due to sequencing errors: 66210
# ------ Final Filtered data saved to: data\step2_filtered\ns3_step2_filtered.csv
# ****************************************************************************************************
# NSP: e
# ------ Original number of rows: 490427
# ------ After Sequencing Error Filtering: 469843
# ------ Total rows discarded due to sequencing errors: 20584
# ------ Final Filtered data saved to: data\step2_filtered\e_step2_filtered.csv
# ****************************************************************************************************
# NSP: m
# ------ Original number of rows: 490369
# ------ After Sequencing Error Filtering: 433731
# ------ Total rows discarded due to sequencing errors: 56638
# ------ Final Filtered data saved to: data\step2_filtered\m_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns6
# ------ Original number of rows: 489257
# ------ After Sequencing Error Filtering: 473497
# ------ Total rows discarded due to sequencing errors: 15760
# ------ Final Filtered data saved to: data\step2_filtered\ns6_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns7a
# ------ Original number of rows: 485714
# ------ After Sequencing Error Filtering: 432586
# ------ Total rows discarded due to sequencing errors: 53128
# ------ Final Filtered data saved to: data\step2_filtered\ns7a_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns7b
# ------ Original number of rows: 489741
# ------ After Sequencing Error Filtering: 441497
# ------ Total rows discarded due to sequencing errors: 48244
# ------ Final Filtered data saved to: data\step2_filtered\ns7b_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns8
# ------ Original number of rows: 288616
# ------ After Sequencing Error Filtering: 242845
# ------ Total rows discarded due to sequencing errors: 45771
# ------ Final Filtered data saved to: data\step2_filtered\ns8_step2_filtered.csv
# ****************************************************************************************************
# NSP: n
# ------ Original number of rows: 350714
# ------ After Sequencing Error Filtering: 291164
# ------ Total rows discarded due to sequencing errors: 59550
# ------ Final Filtered data saved to: data\step2_filtered\n_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns9b
# ------ Original number of rows: 352662
# ------ After Sequencing Error Filtering: 309166
# ------ Total rows discarded due to sequencing errors: 43496
# ------ Final Filtered data saved to: data\step2_filtered\ns9b_step2_filtered.csv
# ****************************************************************************************************
# NSP: ns9c
# ------ Original number of rows: 489639
# ------ After Sequencing Error Filtering: 471552
# ------ Total rows discarded due to sequencing errors: 18087
# ------ Final Filtered data saved to: data\step2_filtered\ns9c_step2_filtered.csv
# ****************************************************************************************************
