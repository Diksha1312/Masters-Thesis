# %%
# imports
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

np.random.seed(7)

import tensorflow as tf
from tensorflow.keras import layers, callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import os
os.getcwd()
os.chdir("../")
# %pwd
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Masters_thesis'

# %%
FILE_DIR = "artifacts"
FILE_PATH = "whole_genome_mutation_rate_1e6_rounded_without_duplicates.csv"

# %%
data = pd.read_csv(os.path.join(FILE_DIR, FILE_PATH))
data.tail()
# Out:
#        AC   AT       AG   CA       CT   CG   TA       TC   TG       GA  \
# 7561  0.0  0.0  0.44503  0.0  1.78013  0.0  0.0  0.00000  0.0  0.89007
# 7562  0.0  0.0  0.44503  0.0  1.78013  0.0  0.0  0.44503  0.0  0.00000
# 7563  0.0  0.0  0.89007  0.0  1.78013  0.0  0.0  0.00000  0.0  0.89007
# 7564  0.0  0.0  0.44503  0.0  1.33510  0.0  0.0  0.44503  0.0  0.00000
# 7565  0.0  0.0  0.89007  0.0  4.89536  0.0  0.0  0.89007  0.0  0.00000
#
#            GC       GT
# 7561  0.44503  0.00000
# 7562  0.00000  0.00000
# 7563  0.44503  0.89007
# 7564  0.00000  0.00000
# 7565  0.44503  0.89007

# %%
dataset = data.values
dataset = dataset.astype('float32')

print('Dataset Shape: ', np.shape(dataset))
# Out:
# Dataset Shape:  (7566, 12)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)


train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 6052 1514

# %%
def create_dataset(dataset, look_back, btch): 
    dataX, dataY = [], []
    z=0
    inc=1
    for i in range(0,len(dataset)-look_back,inc):
        a = dataset[i:(i+look_back)]
        
        dataX.append(np.reshape(a,(btch,12)))
        dataY.append(dataset[i+look_back])
#         print(a,dataY)
        z+=1
    return np.array(dataX), np.array(dataY)
 
btch=12    
look_back = 12
trainX, trainY = create_dataset(train, look_back, btch)
testX, testY = create_dataset(test, look_back, btch)

trainX = np.reshape(trainX, (trainX.shape[0], btch,12))
testX = np.reshape(testX, (testX.shape[0], btch, 12))
print(len(trainX), len(testX))
# Out:
# 6040 1502

# %%
FOLDER_DIR = "final_thesis_notebooks"

# %% [markdown]
# # LSTM

# %%
model = tf.keras.Sequential()
model.add(layers.LSTM(500,activation='relu', input_shape=(btch, 12))) 

model.add(layers.Dense(250))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(50))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(12)) #softmax

model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001))

# Train the model with the ModelCheckpoint callback
history = model.fit(trainX, trainY, validation_split=0.30, epochs=400, batch_size=128, verbose=2)

# Find the minimum validation loss and its respective training loss and epoch
min_val_loss = min(history.history['val_loss'])
min_val_loss_epoch = history.history['val_loss'].index(min_val_loss)
train_loss_at_min_val_loss = history.history['loss'][min_val_loss_epoch]

# Print the results
print(f"Minimum Validation Loss: {min_val_loss} at Epoch {min_val_loss_epoch}")
print(f"Training Loss at Minimum Validation Loss: {train_loss_at_min_val_loss}")
# Out:
# Epoch 1/400
# 34/34 - 8s - loss: 0.0584 - val_loss: 0.0725 - 8s/epoch - 231ms/step
# Epoch 2/400
# 34/34 - 6s - loss: 0.0549 - val_loss: 0.0678 - 6s/epoch - 174ms/step
# Epoch 3/400
# 34/34 - 6s - loss: 0.0511 - val_loss: 0.0625 - 6s/epoch - 168ms/step
# Epoch 4/400
# 34/34 - 6s - loss: 0.0477 - val_loss: 0.0572 - 6s/epoch - 184ms/step
# Epoch 5/400
# 34/34 - 6s - loss: 0.0443 - val_loss: 0.0517 - 6s/epoch - 187ms/step
# Epoch 6/400
# 34/34 - 6s - loss: 0.0415 - val_loss: 0.0465 - 6s/epoch - 185ms/step
# Epoch 7/400
# 34/34 - 6s - loss: 0.0396 - val_loss: 0.0429 - 6s/epoch - 190ms/step
# Epoch 8/400
# 34/34 - 6s - loss: 0.0385 - val_loss: 0.0407 - 6s/epoch - 188ms/step
# Epoch 9/400
# 34/34 - 7s - loss: 0.0381 - val_loss: 0.0394 - 7s/epoch - 192ms/step
# Epoch 10/400
# 34/34 - 6s - loss: 0.0377 - val_loss: 0.0388 - 6s/epoch - 171ms/step
# Epoch 11/400
# 34/34 - 6s - loss: 0.0370 - val_loss: 0.0382 - 6s/epoch - 179ms/step
# Epoch 12/400
# 34/34 - 6s - loss: 0.0366 - val_loss: 0.0375 - 6s/epoch - 179ms/step
# Epoch 13/400
# 34/34 - 6s - loss: 0.0365 - val_loss: 0.0370 - 6s/epoch - 179ms/step
# Epoch 14/400
# 34/34 - 7s - loss: 0.0362 - val_loss: 0.0365 - 7s/epoch - 193ms/step
# Epoch 15/400
# 34/34 - 6s - loss: 0.0359 - val_loss: 0.0363 - 6s/epoch - 190ms/step
# Epoch 16/400
# 34/34 - 7s - loss: 0.0358 - val_loss: 0.0363 - 7s/epoch - 201ms/step
# Epoch 17/400
# 34/34 - 6s - loss: 0.0356 - val_loss: 0.0359 - 6s/epoch - 181ms/step
# Epoch 18/400
# 34/34 - 6s - loss: 0.0354 - val_loss: 0.0356 - 6s/epoch - 180ms/step
# Epoch 19/400
# 34/34 - 6s - loss: 0.0351 - val_loss: 0.0355 - 6s/epoch - 175ms/step
# Epoch 20/400
# 34/34 - 6s - loss: 0.0352 - val_loss: 0.0352 - 6s/epoch - 177ms/step
# Epoch 21/400
# 34/34 - 6s - loss: 0.0348 - val_loss: 0.0352 - 6s/epoch - 181ms/step
# Epoch 22/400
# 34/34 - 6s - loss: 0.0345 - val_loss: 0.0349 - 6s/epoch - 183ms/step
# Epoch 23/400
# 34/34 - 7s - loss: 0.0346 - val_loss: 0.0348 - 7s/epoch - 206ms/step
# Epoch 24/400
# 34/34 - 6s - loss: 0.0344 - val_loss: 0.0346 - 6s/epoch - 189ms/step
# Epoch 25/400
# 34/34 - 9s - loss: 0.0342 - val_loss: 0.0345 - 9s/epoch - 278ms/step
# Epoch 26/400
# 34/34 - 9s - loss: 0.0340 - val_loss: 0.0341 - 9s/epoch - 270ms/step
# Epoch 27/400
# 34/34 - 10s - loss: 0.0337 - val_loss: 0.0340 - 10s/epoch - 295ms/step
# Epoch 28/400
# 34/34 - 10s - loss: 0.0335 - val_loss: 0.0340 - 10s/epoch - 284ms/step
# Epoch 29/400
# 34/34 - 9s - loss: 0.0337 - val_loss: 0.0340 - 9s/epoch - 279ms/step
# Epoch 30/400
# 34/34 - 10s - loss: 0.0336 - val_loss: 0.0338 - 10s/epoch - 296ms/step
# Epoch 31/400
# 34/34 - 10s - loss: 0.0334 - val_loss: 0.0336 - 10s/epoch - 280ms/step
# Epoch 32/400
# 34/34 - 10s - loss: 0.0332 - val_loss: 0.0334 - 10s/epoch - 286ms/step
# Epoch 33/400
# 34/34 - 10s - loss: 0.0330 - val_loss: 0.0334 - 10s/epoch - 300ms/step
# Epoch 34/400
# 34/34 - 10s - loss: 0.0332 - val_loss: 0.0337 - 10s/epoch - 302ms/step
# Epoch 35/400
# 34/34 - 10s - loss: 0.0329 - val_loss: 0.0333 - 10s/epoch - 302ms/step
# Epoch 36/400
# 34/34 - 10s - loss: 0.0332 - val_loss: 0.0331 - 10s/epoch - 294ms/step
# Epoch 37/400
# 34/34 - 9s - loss: 0.0325 - val_loss: 0.0330 - 9s/epoch - 269ms/step
# Epoch 38/400
# 34/34 - 9s - loss: 0.0329 - val_loss: 0.0332 - 9s/epoch - 266ms/step
# Epoch 39/400
# 34/34 - 9s - loss: 0.0323 - val_loss: 0.0329 - 9s/epoch - 266ms/step
# Epoch 40/400
# 34/34 - 9s - loss: 0.0325 - val_loss: 0.0330 - 9s/epoch - 263ms/step
# Epoch 41/400
# 34/34 - 9s - loss: 0.0325 - val_loss: 0.0327 - 9s/epoch - 263ms/step
# Epoch 42/400
# 34/34 - 9s - loss: 0.0323 - val_loss: 0.0325 - 9s/epoch - 262ms/step
# Epoch 43/400
# 34/34 - 9s - loss: 0.0320 - val_loss: 0.0326 - 9s/epoch - 265ms/step
# Epoch 44/400
# 34/34 - 9s - loss: 0.0317 - val_loss: 0.0326 - 9s/epoch - 264ms/step
# Epoch 45/400
# 34/34 - 9s - loss: 0.0321 - val_loss: 0.0328 - 9s/epoch - 266ms/step
# Epoch 46/400
# 34/34 - 9s - loss: 0.0321 - val_loss: 0.0325 - 9s/epoch - 263ms/step
# Epoch 47/400
# 34/34 - 9s - loss: 0.0319 - val_loss: 0.0324 - 9s/epoch - 265ms/step
# Epoch 48/400
# 34/34 - 9s - loss: 0.0314 - val_loss: 0.0322 - 9s/epoch - 264ms/step
# Epoch 49/400
# 34/34 - 9s - loss: 0.0316 - val_loss: 0.0320 - 9s/epoch - 268ms/step
# Epoch 50/400
# 34/34 - 10s - loss: 0.0316 - val_loss: 0.0321 - 10s/epoch - 302ms/step
# Epoch 51/400
# 34/34 - 10s - loss: 0.0314 - val_loss: 0.0320 - 10s/epoch - 290ms/step
# Epoch 52/400
# 34/34 - 10s - loss: 0.0313 - val_loss: 0.0320 - 10s/epoch - 284ms/step
# Epoch 53/400
# 34/34 - 11s - loss: 0.0313 - val_loss: 0.0319 - 11s/epoch - 312ms/step
# Epoch 54/400
# 34/34 - 10s - loss: 0.0310 - val_loss: 0.0319 - 10s/epoch - 295ms/step
# Epoch 55/400
# 34/34 - 10s - loss: 0.0311 - val_loss: 0.0316 - 10s/epoch - 287ms/step
# Epoch 56/400
# 34/34 - 10s - loss: 0.0309 - val_loss: 0.0316 - 10s/epoch - 283ms/step
# Epoch 57/400
# 34/34 - 10s - loss: 0.0309 - val_loss: 0.0316 - 10s/epoch - 289ms/step
# Epoch 58/400
# 34/34 - 10s - loss: 0.0308 - val_loss: 0.0314 - 10s/epoch - 288ms/step
# Epoch 59/400
# 34/34 - 10s - loss: 0.0306 - val_loss: 0.0313 - 10s/epoch - 283ms/step
# Epoch 60/400
# 34/34 - 10s - loss: 0.0307 - val_loss: 0.0315 - 10s/epoch - 291ms/step
# Epoch 61/400
# 34/34 - 10s - loss: 0.0308 - val_loss: 0.0314 - 10s/epoch - 284ms/step
# Epoch 62/400
# 34/34 - 10s - loss: 0.0307 - val_loss: 0.0313 - 10s/epoch - 283ms/step
# Epoch 63/400
# 34/34 - 10s - loss: 0.0305 - val_loss: 0.0312 - 10s/epoch - 281ms/step
# Epoch 64/400
# 34/34 - 10s - loss: 0.0305 - val_loss: 0.0312 - 10s/epoch - 288ms/step
# Epoch 65/400
# 34/34 - 10s - loss: 0.0304 - val_loss: 0.0311 - 10s/epoch - 283ms/step
# Epoch 66/400
# 34/34 - 10s - loss: 0.0303 - val_loss: 0.0311 - 10s/epoch - 285ms/step
# Epoch 67/400
# 34/34 - 10s - loss: 0.0300 - val_loss: 0.0310 - 10s/epoch - 281ms/step
# Epoch 68/400
# 34/34 - 10s - loss: 0.0300 - val_loss: 0.0310 - 10s/epoch - 280ms/step
# Epoch 69/400
# 34/34 - 10s - loss: 0.0303 - val_loss: 0.0310 - 10s/epoch - 283ms/step
# Epoch 70/400
# 34/34 - 10s - loss: 0.0300 - val_loss: 0.0308 - 10s/epoch - 286ms/step
# Epoch 71/400
# 34/34 - 10s - loss: 0.0301 - val_loss: 0.0310 - 10s/epoch - 285ms/step
# Epoch 72/400
# 34/34 - 10s - loss: 0.0298 - val_loss: 0.0311 - 10s/epoch - 285ms/step
# Epoch 73/400
# 34/34 - 10s - loss: 0.0300 - val_loss: 0.0308 - 10s/epoch - 286ms/step
# Epoch 74/400
# 34/34 - 10s - loss: 0.0300 - val_loss: 0.0309 - 10s/epoch - 282ms/step
# Epoch 75/400
# 34/34 - 10s - loss: 0.0298 - val_loss: 0.0305 - 10s/epoch - 287ms/step
# Epoch 76/400
# 34/34 - 10s - loss: 0.0298 - val_loss: 0.0307 - 10s/epoch - 287ms/step
# Epoch 77/400
# 34/34 - 10s - loss: 0.0298 - val_loss: 0.0308 - 10s/epoch - 289ms/step
# Epoch 78/400
# 34/34 - 10s - loss: 0.0298 - val_loss: 0.0308 - 10s/epoch - 288ms/step
# Epoch 79/400
# 34/34 - 10s - loss: 0.0296 - val_loss: 0.0305 - 10s/epoch - 285ms/step
# Epoch 80/400
# 34/34 - 10s - loss: 0.0295 - val_loss: 0.0306 - 10s/epoch - 280ms/step
# Epoch 81/400
# 34/34 - 10s - loss: 0.0295 - val_loss: 0.0304 - 10s/epoch - 285ms/step
# Epoch 82/400
# 34/34 - 10s - loss: 0.0294 - val_loss: 0.0305 - 10s/epoch - 286ms/step
# Epoch 83/400
# 34/34 - 10s - loss: 0.0295 - val_loss: 0.0304 - 10s/epoch - 286ms/step
# Epoch 84/400
# 34/34 - 10s - loss: 0.0296 - val_loss: 0.0306 - 10s/epoch - 284ms/step
# Epoch 85/400
# 34/34 - 10s - loss: 0.0292 - val_loss: 0.0303 - 10s/epoch - 282ms/step
# Epoch 86/400
# 34/34 - 10s - loss: 0.0293 - val_loss: 0.0304 - 10s/epoch - 282ms/step
# Epoch 87/400
# 34/34 - 9s - loss: 0.0289 - val_loss: 0.0302 - 9s/epoch - 278ms/step
# Epoch 88/400
# 34/34 - 10s - loss: 0.0291 - val_loss: 0.0303 - 10s/epoch - 284ms/step
# Epoch 89/400
# 34/34 - 10s - loss: 0.0292 - val_loss: 0.0305 - 10s/epoch - 287ms/step
# Epoch 90/400
# 34/34 - 10s - loss: 0.0292 - val_loss: 0.0303 - 10s/epoch - 290ms/step
# Epoch 91/400
# 34/34 - 10s - loss: 0.0290 - val_loss: 0.0302 - 10s/epoch - 286ms/step
# Epoch 92/400
# 34/34 - 10s - loss: 0.0291 - val_loss: 0.0302 - 10s/epoch - 280ms/step
# Epoch 93/400
# 34/34 - 10s - loss: 0.0290 - val_loss: 0.0302 - 10s/epoch - 281ms/step
# Epoch 94/400
# 34/34 - 10s - loss: 0.0289 - val_loss: 0.0300 - 10s/epoch - 286ms/step
# Epoch 95/400
# 34/34 - 10s - loss: 0.0288 - val_loss: 0.0302 - 10s/epoch - 285ms/step
# Epoch 96/400
# 34/34 - 10s - loss: 0.0286 - val_loss: 0.0299 - 10s/epoch - 286ms/step
# Epoch 97/400
# 34/34 - 10s - loss: 0.0287 - val_loss: 0.0302 - 10s/epoch - 285ms/step
# Epoch 98/400
# 34/34 - 10s - loss: 0.0287 - val_loss: 0.0301 - 10s/epoch - 280ms/step
# Epoch 99/400
# 34/34 - 9s - loss: 0.0286 - val_loss: 0.0300 - 9s/epoch - 278ms/step
# Epoch 100/400
# 34/34 - 10s - loss: 0.0286 - val_loss: 0.0302 - 10s/epoch - 285ms/step
# Epoch 101/400
# 34/34 - 10s - loss: 0.0283 - val_loss: 0.0298 - 10s/epoch - 282ms/step
# Epoch 102/400
# 34/34 - 10s - loss: 0.0285 - val_loss: 0.0300 - 10s/epoch - 282ms/step
# Epoch 103/400
# 34/34 - 10s - loss: 0.0283 - val_loss: 0.0297 - 10s/epoch - 287ms/step
# Epoch 104/400
# 34/34 - 10s - loss: 0.0282 - val_loss: 0.0298 - 10s/epoch - 283ms/step
# Epoch 105/400
# 34/34 - 9s - loss: 0.0284 - val_loss: 0.0300 - 9s/epoch - 276ms/step
# Epoch 106/400
# 34/34 - 10s - loss: 0.0284 - val_loss: 0.0298 - 10s/epoch - 290ms/step
# Epoch 107/400
# 34/34 - 10s - loss: 0.0282 - val_loss: 0.0297 - 10s/epoch - 285ms/step
# Epoch 108/400
# 34/34 - 10s - loss: 0.0282 - val_loss: 0.0298 - 10s/epoch - 286ms/step
# Epoch 109/400
# 34/34 - 10s - loss: 0.0279 - val_loss: 0.0297 - 10s/epoch - 285ms/step
# Epoch 110/400
# 34/34 - 10s - loss: 0.0280 - val_loss: 0.0297 - 10s/epoch - 290ms/step
# Epoch 111/400
# 34/34 - 10s - loss: 0.0281 - val_loss: 0.0297 - 10s/epoch - 288ms/step
# Epoch 112/400
# 34/34 - 10s - loss: 0.0280 - val_loss: 0.0298 - 10s/epoch - 289ms/step
# Epoch 113/400
# 34/34 - 11s - loss: 0.0281 - val_loss: 0.0297 - 11s/epoch - 319ms/step
# Epoch 114/400
# 34/34 - 10s - loss: 0.0280 - val_loss: 0.0297 - 10s/epoch - 292ms/step
# Epoch 115/400
# 34/34 - 10s - loss: 0.0279 - val_loss: 0.0296 - 10s/epoch - 286ms/step
# Epoch 116/400
# 34/34 - 10s - loss: 0.0279 - val_loss: 0.0297 - 10s/epoch - 283ms/step
# Epoch 117/400
# 34/34 - 10s - loss: 0.0278 - val_loss: 0.0294 - 10s/epoch - 281ms/step
# Epoch 118/400
# 34/34 - 10s - loss: 0.0279 - val_loss: 0.0295 - 10s/epoch - 280ms/step
# Epoch 119/400
# 34/34 - 10s - loss: 0.0278 - val_loss: 0.0296 - 10s/epoch - 284ms/step
# Epoch 120/400
# 34/34 - 10s - loss: 0.0279 - val_loss: 0.0295 - 10s/epoch - 281ms/step
# Epoch 121/400
# 34/34 - 10s - loss: 0.0277 - val_loss: 0.0295 - 10s/epoch - 286ms/step
# Epoch 122/400
# 34/34 - 10s - loss: 0.0277 - val_loss: 0.0295 - 10s/epoch - 287ms/step
# Epoch 123/400
# 34/34 - 10s - loss: 0.0277 - val_loss: 0.0294 - 10s/epoch - 286ms/step
# Epoch 124/400
# 34/34 - 10s - loss: 0.0275 - val_loss: 0.0293 - 10s/epoch - 282ms/step
# Epoch 125/400
# 34/34 - 10s - loss: 0.0275 - val_loss: 0.0293 - 10s/epoch - 288ms/step
# Epoch 126/400
# 34/34 - 10s - loss: 0.0274 - val_loss: 0.0293 - 10s/epoch - 288ms/step
# Epoch 127/400
# 34/34 - 10s - loss: 0.0274 - val_loss: 0.0295 - 10s/epoch - 290ms/step
# Epoch 128/400
# 34/34 - 10s - loss: 0.0275 - val_loss: 0.0293 - 10s/epoch - 285ms/step
# Epoch 129/400
# 34/34 - 10s - loss: 0.0275 - val_loss: 0.0292 - 10s/epoch - 285ms/step
# Epoch 130/400
# 34/34 - 9s - loss: 0.0275 - val_loss: 0.0293 - 9s/epoch - 279ms/step
# Epoch 131/400
# 34/34 - 10s - loss: 0.0274 - val_loss: 0.0292 - 10s/epoch - 286ms/step
# Epoch 132/400
# 34/34 - 10s - loss: 0.0272 - val_loss: 0.0292 - 10s/epoch - 287ms/step
# Epoch 133/400
# 34/34 - 10s - loss: 0.0274 - val_loss: 0.0293 - 10s/epoch - 290ms/step
# Epoch 134/400
# 34/34 - 10s - loss: 0.0273 - val_loss: 0.0293 - 10s/epoch - 286ms/step
# Epoch 135/400
# 34/34 - 10s - loss: 0.0272 - val_loss: 0.0292 - 10s/epoch - 286ms/step
# Epoch 136/400
# 34/34 - 10s - loss: 0.0273 - val_loss: 0.0293 - 10s/epoch - 285ms/step
# Epoch 137/400
# 34/34 - 10s - loss: 0.0273 - val_loss: 0.0293 - 10s/epoch - 284ms/step
# Epoch 138/400
# 34/34 - 10s - loss: 0.0272 - val_loss: 0.0293 - 10s/epoch - 288ms/step
# Epoch 139/400
# 34/34 - 10s - loss: 0.0272 - val_loss: 0.0292 - 10s/epoch - 286ms/step
# Epoch 140/400
# 34/34 - 10s - loss: 0.0271 - val_loss: 0.0292 - 10s/epoch - 284ms/step
# Epoch 141/400
# 34/34 - 10s - loss: 0.0268 - val_loss: 0.0292 - 10s/epoch - 283ms/step
# Epoch 142/400
# 34/34 - 10s - loss: 0.0269 - val_loss: 0.0290 - 10s/epoch - 282ms/step
# Epoch 143/400
# 34/34 - 10s - loss: 0.0269 - val_loss: 0.0291 - 10s/epoch - 281ms/step
# Epoch 144/400
# 34/34 - 10s - loss: 0.0270 - val_loss: 0.0293 - 10s/epoch - 285ms/step
# Epoch 145/400
# 34/34 - 10s - loss: 0.0269 - val_loss: 0.0291 - 10s/epoch - 286ms/step
# Epoch 146/400
# 34/34 - 10s - loss: 0.0268 - val_loss: 0.0292 - 10s/epoch - 286ms/step
# Epoch 147/400
# 34/34 - 10s - loss: 0.0267 - val_loss: 0.0288 - 10s/epoch - 285ms/step
# Epoch 148/400
# 34/34 - 10s - loss: 0.0267 - val_loss: 0.0292 - 10s/epoch - 284ms/step
# Epoch 149/400
# 34/34 - 10s - loss: 0.0267 - val_loss: 0.0291 - 10s/epoch - 282ms/step
# Epoch 150/400
# 34/34 - 10s - loss: 0.0267 - val_loss: 0.0290 - 10s/epoch - 286ms/step
# Epoch 151/400
# 34/34 - 11s - loss: 0.0266 - val_loss: 0.0288 - 11s/epoch - 311ms/step
# Epoch 152/400
# 34/34 - 11s - loss: 0.0265 - val_loss: 0.0289 - 11s/epoch - 329ms/step
# Epoch 153/400
# 34/34 - 10s - loss: 0.0267 - val_loss: 0.0289 - 10s/epoch - 308ms/step
# Epoch 154/400
# 34/34 - 10s - loss: 0.0265 - val_loss: 0.0289 - 10s/epoch - 304ms/step
# Epoch 155/400
# 34/34 - 12s - loss: 0.0265 - val_loss: 0.0289 - 12s/epoch - 361ms/step
# Epoch 156/400
# 34/34 - 11s - loss: 0.0267 - val_loss: 0.0290 - 11s/epoch - 323ms/step
# Epoch 157/400
# 34/34 - 10s - loss: 0.0265 - val_loss: 0.0290 - 10s/epoch - 307ms/step
# Epoch 158/400
# 34/34 - 10s - loss: 0.0264 - val_loss: 0.0289 - 10s/epoch - 287ms/step
# Epoch 159/400
# 34/34 - 10s - loss: 0.0264 - val_loss: 0.0290 - 10s/epoch - 285ms/step
# Epoch 160/400
# 34/34 - 10s - loss: 0.0265 - val_loss: 0.0289 - 10s/epoch - 290ms/step
# Epoch 161/400
# 34/34 - 10s - loss: 0.0265 - val_loss: 0.0289 - 10s/epoch - 282ms/step
# Epoch 162/400
# 34/34 - 10s - loss: 0.0263 - val_loss: 0.0288 - 10s/epoch - 285ms/step
# Epoch 163/400
# 34/34 - 10s - loss: 0.0263 - val_loss: 0.0288 - 10s/epoch - 286ms/step
# Epoch 164/400
# 34/34 - 10s - loss: 0.0265 - val_loss: 0.0290 - 10s/epoch - 293ms/step
# Epoch 165/400
# 34/34 - 10s - loss: 0.0263 - val_loss: 0.0288 - 10s/epoch - 289ms/step
# Epoch 166/400
# 34/34 - 10s - loss: 0.0263 - val_loss: 0.0290 - 10s/epoch - 284ms/step
# Epoch 167/400
# 34/34 - 10s - loss: 0.0260 - val_loss: 0.0289 - 10s/epoch - 284ms/step
# Epoch 168/400
# 34/34 - 10s - loss: 0.0263 - val_loss: 0.0289 - 10s/epoch - 287ms/step
# Epoch 169/400
# 34/34 - 10s - loss: 0.0262 - val_loss: 0.0288 - 10s/epoch - 289ms/step
# Epoch 170/400
# 34/34 - 10s - loss: 0.0261 - val_loss: 0.0290 - 10s/epoch - 290ms/step
# Epoch 171/400
# 34/34 - 10s - loss: 0.0260 - val_loss: 0.0288 - 10s/epoch - 291ms/step
# Epoch 172/400
# 34/34 - 10s - loss: 0.0261 - val_loss: 0.0289 - 10s/epoch - 298ms/step
# Epoch 173/400
# 34/34 - 10s - loss: 0.0260 - val_loss: 0.0287 - 10s/epoch - 284ms/step
# Epoch 174/400
# 34/34 - 10s - loss: 0.0261 - val_loss: 0.0290 - 10s/epoch - 285ms/step
# Epoch 175/400
# 34/34 - 10s - loss: 0.0260 - val_loss: 0.0288 - 10s/epoch - 286ms/step
# Epoch 176/400
# 34/34 - 10s - loss: 0.0260 - val_loss: 0.0288 - 10s/epoch - 293ms/step
# Epoch 177/400
# 34/34 - 10s - loss: 0.0258 - val_loss: 0.0287 - 10s/epoch - 295ms/step
# Epoch 178/400
# 34/34 - 10s - loss: 0.0259 - val_loss: 0.0288 - 10s/epoch - 295ms/step
# Epoch 179/400
# 34/34 - 10s - loss: 0.0261 - val_loss: 0.0288 - 10s/epoch - 284ms/step
# Epoch 180/400
# 34/34 - 10s - loss: 0.0259 - val_loss: 0.0287 - 10s/epoch - 289ms/step
# Epoch 181/400
# 34/34 - 11s - loss: 0.0258 - val_loss: 0.0286 - 11s/epoch - 321ms/step
# Epoch 182/400
# 34/34 - 10s - loss: 0.0259 - val_loss: 0.0286 - 10s/epoch - 290ms/step
# Epoch 183/400
# 34/34 - 10s - loss: 0.0257 - val_loss: 0.0287 - 10s/epoch - 291ms/step
# Epoch 184/400
# 34/34 - 10s - loss: 0.0259 - val_loss: 0.0288 - 10s/epoch - 283ms/step
# Epoch 185/400
# 34/34 - 10s - loss: 0.0259 - val_loss: 0.0288 - 10s/epoch - 284ms/step
# Epoch 186/400
# 34/34 - 10s - loss: 0.0258 - val_loss: 0.0286 - 10s/epoch - 296ms/step
# Epoch 187/400
# 34/34 - 10s - loss: 0.0256 - val_loss: 0.0286 - 10s/epoch - 301ms/step
# Epoch 188/400
# 34/34 - 11s - loss: 0.0257 - val_loss: 0.0287 - 11s/epoch - 321ms/step
# Epoch 189/400
# 34/34 - 10s - loss: 0.0255 - val_loss: 0.0285 - 10s/epoch - 309ms/step
# Epoch 190/400
# 34/34 - 10s - loss: 0.0257 - val_loss: 0.0286 - 10s/epoch - 295ms/step
# Epoch 191/400
# 34/34 - 10s - loss: 0.0257 - val_loss: 0.0285 - 10s/epoch - 299ms/step
# Epoch 192/400
# 34/34 - 11s - loss: 0.0258 - val_loss: 0.0284 - 11s/epoch - 333ms/step
# Epoch 193/400
# 34/34 - 11s - loss: 0.0257 - val_loss: 0.0286 - 11s/epoch - 325ms/step
# Epoch 194/400
# 34/34 - 10s - loss: 0.0257 - val_loss: 0.0287 - 10s/epoch - 287ms/step
# Epoch 195/400
# 34/34 - 10s - loss: 0.0256 - val_loss: 0.0287 - 10s/epoch - 289ms/step
# Epoch 196/400
# 34/34 - 9s - loss: 0.0257 - val_loss: 0.0287 - 9s/epoch - 277ms/step
# Epoch 197/400
# 34/34 - 10s - loss: 0.0255 - val_loss: 0.0286 - 10s/epoch - 284ms/step
# Epoch 198/400
# 34/34 - 10s - loss: 0.0254 - val_loss: 0.0287 - 10s/epoch - 290ms/step
# Epoch 199/400
# 34/34 - 10s - loss: 0.0254 - val_loss: 0.0285 - 10s/epoch - 289ms/step
# Epoch 200/400
# 34/34 - 10s - loss: 0.0255 - val_loss: 0.0286 - 10s/epoch - 291ms/step
# Epoch 201/400
# 34/34 - 10s - loss: 0.0254 - val_loss: 0.0286 - 10s/epoch - 289ms/step
# Epoch 202/400
# 34/34 - 9s - loss: 0.0254 - val_loss: 0.0284 - 9s/epoch - 269ms/step
# Epoch 203/400
# 34/34 - 9s - loss: 0.0252 - val_loss: 0.0285 - 9s/epoch - 269ms/step
# Epoch 204/400
# 34/34 - 9s - loss: 0.0253 - val_loss: 0.0286 - 9s/epoch - 266ms/step
# Epoch 205/400
# 34/34 - 9s - loss: 0.0255 - val_loss: 0.0285 - 9s/epoch - 266ms/step
# Epoch 206/400
# 34/34 - 9s - loss: 0.0254 - val_loss: 0.0285 - 9s/epoch - 269ms/step
# Epoch 207/400
# 34/34 - 9s - loss: 0.0253 - val_loss: 0.0286 - 9s/epoch - 270ms/step
# Epoch 208/400
# 34/34 - 9s - loss: 0.0253 - val_loss: 0.0285 - 9s/epoch - 269ms/step
# Epoch 209/400
# 34/34 - 10s - loss: 0.0253 - val_loss: 0.0286 - 10s/epoch - 285ms/step
# Epoch 210/400
# 34/34 - 10s - loss: 0.0253 - val_loss: 0.0286 - 10s/epoch - 287ms/step
# Epoch 211/400
# 34/34 - 10s - loss: 0.0252 - val_loss: 0.0286 - 10s/epoch - 291ms/step
# Epoch 212/400
# 34/34 - 10s - loss: 0.0253 - val_loss: 0.0285 - 10s/epoch - 290ms/step
# Epoch 213/400
# 34/34 - 10s - loss: 0.0252 - val_loss: 0.0285 - 10s/epoch - 286ms/step
# Epoch 214/400
# 34/34 - 10s - loss: 0.0252 - val_loss: 0.0285 - 10s/epoch - 284ms/step
# Epoch 215/400
# 34/34 - 10s - loss: 0.0253 - val_loss: 0.0284 - 10s/epoch - 284ms/step
# Epoch 216/400
# 34/34 - 10s - loss: 0.0251 - val_loss: 0.0285 - 10s/epoch - 285ms/step
# Epoch 217/400
# 34/34 - 10s - loss: 0.0253 - val_loss: 0.0285 - 10s/epoch - 285ms/step
# Epoch 218/400
# 34/34 - 10s - loss: 0.0251 - val_loss: 0.0284 - 10s/epoch - 285ms/step
# Epoch 219/400
# 34/34 - 10s - loss: 0.0251 - val_loss: 0.0283 - 10s/epoch - 280ms/step
# Epoch 220/400
# 34/34 - 10s - loss: 0.0250 - val_loss: 0.0283 - 10s/epoch - 283ms/step
# Epoch 221/400
# 34/34 - 10s - loss: 0.0250 - val_loss: 0.0284 - 10s/epoch - 284ms/step
# Epoch 222/400
# 34/34 - 10s - loss: 0.0251 - val_loss: 0.0284 - 10s/epoch - 285ms/step
# Epoch 223/400
# 34/34 - 10s - loss: 0.0250 - val_loss: 0.0283 - 10s/epoch - 284ms/step
# Epoch 224/400
# 34/34 - 10s - loss: 0.0249 - val_loss: 0.0283 - 10s/epoch - 284ms/step
# Epoch 225/400
# 34/34 - 9s - loss: 0.0251 - val_loss: 0.0284 - 9s/epoch - 277ms/step
# Epoch 226/400
# 34/34 - 10s - loss: 0.0250 - val_loss: 0.0284 - 10s/epoch - 284ms/step
# Epoch 227/400
# 34/34 - 10s - loss: 0.0251 - val_loss: 0.0285 - 10s/epoch - 286ms/step
# Epoch 228/400
# 34/34 - 10s - loss: 0.0249 - val_loss: 0.0283 - 10s/epoch - 285ms/step
# Epoch 229/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0283 - 10s/epoch - 288ms/step
# Epoch 230/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0284 - 10s/epoch - 285ms/step
# Epoch 231/400
# 34/34 - 10s - loss: 0.0249 - val_loss: 0.0283 - 10s/epoch - 281ms/step
# Epoch 232/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0284 - 10s/epoch - 288ms/step
# Epoch 233/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0283 - 10s/epoch - 291ms/step
# Epoch 234/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0283 - 10s/epoch - 290ms/step
# Epoch 235/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0283 - 10s/epoch - 283ms/step
# Epoch 236/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0283 - 10s/epoch - 281ms/step
# Epoch 237/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0283 - 10s/epoch - 282ms/step
# Epoch 238/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0284 - 10s/epoch - 285ms/step
# Epoch 239/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0283 - 10s/epoch - 283ms/step
# Epoch 240/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0283 - 10s/epoch - 283ms/step
# Epoch 241/400
# 34/34 - 10s - loss: 0.0248 - val_loss: 0.0283 - 10s/epoch - 284ms/step
# Epoch 242/400
# 34/34 - 9s - loss: 0.0246 - val_loss: 0.0283 - 9s/epoch - 279ms/step
# Epoch 243/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0283 - 10s/epoch - 282ms/step
# Epoch 244/400
# 34/34 - 10s - loss: 0.0246 - val_loss: 0.0282 - 10s/epoch - 285ms/step
# Epoch 245/400
# 34/34 - 10s - loss: 0.0247 - val_loss: 0.0284 - 10s/epoch - 286ms/step
# Epoch 246/400
# 34/34 - 10s - loss: 0.0246 - val_loss: 0.0283 - 10s/epoch - 286ms/step
# Epoch 247/400
# 34/34 - 10s - loss: 0.0245 - val_loss: 0.0283 - 10s/epoch - 284ms/step
# Epoch 248/400
# 34/34 - 9s - loss: 0.0245 - val_loss: 0.0283 - 9s/epoch - 278ms/step
# Epoch 249/400
# 34/34 - 10s - loss: 0.0245 - val_loss: 0.0282 - 10s/epoch - 284ms/step
# Epoch 250/400
# 34/34 - 10s - loss: 0.0245 - val_loss: 0.0284 - 10s/epoch - 282ms/step
# Epoch 251/400
# 34/34 - 10s - loss: 0.0246 - val_loss: 0.0282 - 10s/epoch - 286ms/step
# Epoch 252/400
# 34/34 - 10s - loss: 0.0246 - val_loss: 0.0282 - 10s/epoch - 284ms/step
# Epoch 253/400
# 34/34 - 10s - loss: 0.0246 - val_loss: 0.0284 - 10s/epoch - 284ms/step
# Epoch 254/400
# 34/34 - 10s - loss: 0.0245 - val_loss: 0.0281 - 10s/epoch - 282ms/step
# Epoch 255/400
# 34/34 - 10s - loss: 0.0245 - val_loss: 0.0282 - 10s/epoch - 287ms/step
# Epoch 256/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0282 - 10s/epoch - 287ms/step
# Epoch 257/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0283 - 10s/epoch - 288ms/step
# Epoch 258/400
# 34/34 - 10s - loss: 0.0245 - val_loss: 0.0283 - 10s/epoch - 288ms/step
# Epoch 259/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0284 - 10s/epoch - 284ms/step
# Epoch 260/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0285 - 10s/epoch - 291ms/step
# Epoch 261/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0283 - 10s/epoch - 295ms/step
# Epoch 262/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0282 - 10s/epoch - 291ms/step
# Epoch 263/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0284 - 10s/epoch - 292ms/step
# Epoch 264/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0281 - 10s/epoch - 292ms/step
# Epoch 265/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0281 - 10s/epoch - 286ms/step
# Epoch 266/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0283 - 10s/epoch - 293ms/step
# Epoch 267/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0281 - 10s/epoch - 290ms/step
# Epoch 268/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0282 - 10s/epoch - 289ms/step
# Epoch 269/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0282 - 10s/epoch - 288ms/step
# Epoch 270/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0283 - 10s/epoch - 284ms/step
# Epoch 271/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0281 - 10s/epoch - 281ms/step
# Epoch 272/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0283 - 10s/epoch - 286ms/step
# Epoch 273/400
# 34/34 - 10s - loss: 0.0244 - val_loss: 0.0281 - 10s/epoch - 293ms/step
# Epoch 274/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0283 - 10s/epoch - 291ms/step
# Epoch 275/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0282 - 10s/epoch - 292ms/step
# Epoch 276/400
# 34/34 - 10s - loss: 0.0243 - val_loss: 0.0282 - 10s/epoch - 284ms/step
# Epoch 277/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0282 - 10s/epoch - 281ms/step
# Epoch 278/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0281 - 10s/epoch - 290ms/step
# Epoch 279/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0281 - 10s/epoch - 288ms/step
# Epoch 280/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0282 - 10s/epoch - 293ms/step
# Epoch 281/400
# 34/34 - 10s - loss: 0.0242 - val_loss: 0.0281 - 10s/epoch - 294ms/step
# Epoch 282/400
# 34/34 - 10s - loss: 0.0241 - val_loss: 0.0282 - 10s/epoch - 279ms/step
# Epoch 283/400
# 34/34 - 10s - loss: 0.0241 - val_loss: 0.0283 - 10s/epoch - 281ms/step
# Epoch 284/400
# 34/34 - 10s - loss: 0.0240 - val_loss: 0.0281 - 10s/epoch - 283ms/step
# Epoch 285/400
# 34/34 - 10s - loss: 0.0240 - val_loss: 0.0282 - 10s/epoch - 289ms/step
# Epoch 286/400
# 34/34 - 10s - loss: 0.0241 - val_loss: 0.0280 - 10s/epoch - 286ms/step
# Epoch 287/400
# 34/34 - 10s - loss: 0.0241 - val_loss: 0.0281 - 10s/epoch - 284ms/step
# Epoch 288/400
# 34/34 - 9s - loss: 0.0240 - val_loss: 0.0280 - 9s/epoch - 278ms/step
# Epoch 289/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 282ms/step
# Epoch 290/400
# 34/34 - 10s - loss: 0.0241 - val_loss: 0.0281 - 10s/epoch - 282ms/step
# Epoch 291/400
# 34/34 - 10s - loss: 0.0241 - val_loss: 0.0281 - 10s/epoch - 290ms/step
# Epoch 292/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 293/400
# 34/34 - 10s - loss: 0.0240 - val_loss: 0.0279 - 10s/epoch - 287ms/step
# Epoch 294/400
# 34/34 - 9s - loss: 0.0240 - val_loss: 0.0280 - 9s/epoch - 279ms/step
# Epoch 295/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 296/400
# 34/34 - 10s - loss: 0.0238 - val_loss: 0.0279 - 10s/epoch - 286ms/step
# Epoch 297/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 283ms/step
# Epoch 298/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 286ms/step
# Epoch 299/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 285ms/step
# Epoch 300/400
# 34/34 - 9s - loss: 0.0239 - val_loss: 0.0282 - 9s/epoch - 277ms/step
# Epoch 301/400
# 34/34 - 10s - loss: 0.0240 - val_loss: 0.0281 - 10s/epoch - 283ms/step
# Epoch 302/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0280 - 10s/epoch - 286ms/step
# Epoch 303/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 304/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 282ms/step
# Epoch 305/400
# 34/34 - 10s - loss: 0.0238 - val_loss: 0.0282 - 10s/epoch - 282ms/step
# Epoch 306/400
# 34/34 - 9s - loss: 0.0239 - val_loss: 0.0280 - 9s/epoch - 276ms/step
# Epoch 307/400
# 34/34 - 10s - loss: 0.0238 - val_loss: 0.0280 - 10s/epoch - 295ms/step
# Epoch 308/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0280 - 10s/epoch - 297ms/step
# Epoch 309/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0280 - 10s/epoch - 290ms/step
# Epoch 310/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 286ms/step
# Epoch 311/400
# 34/34 - 10s - loss: 0.0239 - val_loss: 0.0281 - 10s/epoch - 287ms/step
# Epoch 312/400
# 34/34 - 9s - loss: 0.0238 - val_loss: 0.0280 - 9s/epoch - 277ms/step
# Epoch 313/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0280 - 10s/epoch - 281ms/step
# Epoch 314/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0280 - 10s/epoch - 296ms/step
# Epoch 315/400
# 34/34 - 10s - loss: 0.0238 - val_loss: 0.0280 - 10s/epoch - 292ms/step
# Epoch 316/400
# 34/34 - 11s - loss: 0.0236 - val_loss: 0.0281 - 11s/epoch - 320ms/step
# Epoch 317/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0281 - 10s/epoch - 306ms/step
# Epoch 318/400
# 34/34 - 9s - loss: 0.0237 - val_loss: 0.0280 - 9s/epoch - 277ms/step
# Epoch 319/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0280 - 10s/epoch - 281ms/step
# Epoch 320/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0279 - 10s/epoch - 281ms/step
# Epoch 321/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0281 - 10s/epoch - 285ms/step
# Epoch 322/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0280 - 10s/epoch - 282ms/step
# Epoch 323/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0281 - 10s/epoch - 283ms/step
# Epoch 324/400
# 34/34 - 9s - loss: 0.0237 - val_loss: 0.0281 - 9s/epoch - 279ms/step
# Epoch 325/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0279 - 10s/epoch - 280ms/step
# Epoch 326/400
# 34/34 - 10s - loss: 0.0237 - val_loss: 0.0280 - 10s/epoch - 281ms/step
# Epoch 327/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0280 - 10s/epoch - 289ms/step
# Epoch 328/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 285ms/step
# Epoch 329/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0282 - 10s/epoch - 283ms/step
# Epoch 330/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0280 - 10s/epoch - 283ms/step
# Epoch 331/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0281 - 10s/epoch - 281ms/step
# Epoch 332/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 333/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 282ms/step
# Epoch 334/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0281 - 10s/epoch - 283ms/step
# Epoch 335/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0279 - 10s/epoch - 284ms/step
# Epoch 336/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0280 - 10s/epoch - 281ms/step
# Epoch 337/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0280 - 10s/epoch - 288ms/step
# Epoch 338/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 339/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0281 - 10s/epoch - 283ms/step
# Epoch 340/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 286ms/step
# Epoch 341/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0280 - 10s/epoch - 283ms/step
# Epoch 342/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 343/400
# 34/34 - 10s - loss: 0.0236 - val_loss: 0.0280 - 10s/epoch - 283ms/step
# Epoch 344/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0281 - 10s/epoch - 295ms/step
# Epoch 345/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 290ms/step
# Epoch 346/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 296ms/step
# Epoch 347/400
# 34/34 - 12s - loss: 0.0235 - val_loss: 0.0279 - 12s/epoch - 342ms/step
# Epoch 348/400
# 34/34 - 11s - loss: 0.0235 - val_loss: 0.0280 - 11s/epoch - 314ms/step
# Epoch 349/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0280 - 10s/epoch - 284ms/step
# Epoch 350/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0280 - 10s/epoch - 290ms/step
# Epoch 351/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0280 - 10s/epoch - 288ms/step
# Epoch 352/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0280 - 10s/epoch - 288ms/step
# Epoch 353/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0280 - 10s/epoch - 288ms/step
# Epoch 354/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0280 - 10s/epoch - 280ms/step
# Epoch 355/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0279 - 10s/epoch - 283ms/step
# Epoch 356/400
# 34/34 - 10s - loss: 0.0232 - val_loss: 0.0279 - 10s/epoch - 288ms/step
# Epoch 357/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0280 - 10s/epoch - 289ms/step
# Epoch 358/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0279 - 10s/epoch - 289ms/step
# Epoch 359/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0278 - 10s/epoch - 286ms/step
# Epoch 360/400
# 34/34 - 10s - loss: 0.0235 - val_loss: 0.0279 - 10s/epoch - 281ms/step
# Epoch 361/400
# 34/34 - 10s - loss: 0.0232 - val_loss: 0.0279 - 10s/epoch - 281ms/step
# Epoch 362/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0279 - 10s/epoch - 284ms/step
# Epoch 363/400
# 34/34 - 10s - loss: 0.0232 - val_loss: 0.0278 - 10s/epoch - 286ms/step
# Epoch 364/400
# 34/34 - 10s - loss: 0.0234 - val_loss: 0.0278 - 10s/epoch - 286ms/step
# Epoch 365/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0279 - 10s/epoch - 284ms/step
# Epoch 366/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0279 - 10s/epoch - 282ms/step
# Epoch 367/400
# 34/34 - 10s - loss: 0.0233 - val_loss: 0.0279 - 10s/epoch - 282ms/step
# Epoch 368/400
# 34/34 - 9s - loss: 0.0232 - val_loss: 0.0277 - 9s/epoch - 259ms/step
# Epoch 369/400
# 34/34 - 7s - loss: 0.0232 - val_loss: 0.0279 - 7s/epoch - 220ms/step
# Epoch 370/400
# 34/34 - 8s - loss: 0.0232 - val_loss: 0.0279 - 8s/epoch - 230ms/step
# Epoch 371/400
# 34/34 - 6s - loss: 0.0232 - val_loss: 0.0278 - 6s/epoch - 166ms/step
# Epoch 372/400
# 34/34 - 6s - loss: 0.0233 - val_loss: 0.0279 - 6s/epoch - 163ms/step
# Epoch 373/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0279 - 5s/epoch - 157ms/step
# Epoch 374/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0278 - 5s/epoch - 157ms/step
# Epoch 375/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0278 - 5s/epoch - 158ms/step
# Epoch 376/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 160ms/step
# Epoch 377/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0279 - 5s/epoch - 156ms/step
# Epoch 378/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0278 - 5s/epoch - 162ms/step
# Epoch 379/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0278 - 5s/epoch - 155ms/step
# Epoch 380/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0278 - 5s/epoch - 155ms/step
# Epoch 381/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 156ms/step
# Epoch 382/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 154ms/step
# Epoch 383/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 155ms/step
# Epoch 384/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0278 - 5s/epoch - 155ms/step
# Epoch 385/400
# 34/34 - 5s - loss: 0.0232 - val_loss: 0.0279 - 5s/epoch - 154ms/step
# Epoch 386/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 153ms/step
# Epoch 387/400
# 34/34 - 5s - loss: 0.0230 - val_loss: 0.0279 - 5s/epoch - 158ms/step
# Epoch 388/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0277 - 5s/epoch - 157ms/step
# Epoch 389/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0280 - 5s/epoch - 158ms/step
# Epoch 390/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 156ms/step
# Epoch 391/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 156ms/step
# Epoch 392/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0279 - 5s/epoch - 158ms/step
# Epoch 393/400
# 34/34 - 5s - loss: 0.0230 - val_loss: 0.0277 - 5s/epoch - 158ms/step
# Epoch 394/400
# 34/34 - 5s - loss: 0.0230 - val_loss: 0.0279 - 5s/epoch - 157ms/step
# Epoch 395/400
# 34/34 - 5s - loss: 0.0230 - val_loss: 0.0278 - 5s/epoch - 157ms/step
# Epoch 396/400
# 34/34 - 5s - loss: 0.0230 - val_loss: 0.0278 - 5s/epoch - 159ms/step
# Epoch 397/400
# 34/34 - 6s - loss: 0.0230 - val_loss: 0.0278 - 6s/epoch - 162ms/step
# Epoch 398/400
# 34/34 - 6s - loss: 0.0229 - val_loss: 0.0279 - 6s/epoch - 165ms/step
# Epoch 399/400
# 34/34 - 5s - loss: 0.0230 - val_loss: 0.0279 - 5s/epoch - 159ms/step
# Epoch 400/400
# 34/34 - 5s - loss: 0.0231 - val_loss: 0.0278 - 5s/epoch - 158ms/step
# Minimum Validation Loss: 0.027705105021595955 at Epoch 367
# Training Loss at Minimum Validation Loss: 0.023167584091424942

# %%
plt.plot(history.history['loss'])
plt.plot(np.array(history.history['val_loss']))
plt.title('Model loss')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig(os.path.join(FOLDER_DIR, "plots", 'lstm_model_loss_plot.png'), dpi=400)
plt.show()

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)


# invert predictions

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY)
# Out:
# 189/189 [==============================] - 6s 33ms/step
# 47/47 [==============================] - 1s 31ms/step

# %%
#calculating error

trainScore_rmse = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train RMSE: %.2f RMSE' % (trainScore_rmse))
testScore_rmse = math.sqrt(mean_squared_error(testY, testPredict))
print('Test RMSE: %.2f RMSE' % (testScore_rmse))

trainScore_mae = mean_absolute_error(trainY, trainPredict)
print('Train MAE: %.2f MAE' % (trainScore_mae))
testScore_mae = mean_absolute_error(testY, testPredict)
print('Test MAE: %.2f MAE' % (trainScore_mae))

trainScore_mse = mean_squared_error(trainY, trainPredict)
print('Train MSE: %.2f MSE' % (trainScore_mse))
testScore_mse = mean_squared_error(testY, testPredict)
print('Test MSE: %.2f MSE' % (trainScore_mse))
# Out:
# Train RMSE: 0.61 RMSE
# Test RMSE: 0.61 RMSE
# Train MAE: 0.38 MAE
# Test MAE: 0.38 MAE
# Train MSE: 0.37 MSE
# Test MSE: 0.37 MSE

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 500)               1026000
#
#  dense (Dense)               (None, 250)               125250
#
#  activation (Activation)     (None, 250)               0
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense_1 (Dense)             (None, 50)                12550
#
#  activation_1 (Activation)   (None, 50)                0
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 12)                612
#
# =================================================================
# Total params: 1164412 (4.44 MB)
# Trainable params: 1164412 (4.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# FOLDER_DIR = "final_thesis_notebooks"
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file=os.path.join(FOLDER_DIR, "models", "model_plot_lstm.png"), 
#            show_shapes=True, show_layer_names=False, dpi='600')

# %%
model

# %%
plt.plot(history.history['loss'])
plt.plot(np.array(history.history['val_loss']))
plt.title('Model loss')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig(os.path.join(FOLDER_DIR, "plots", 'lstm_model_loss_plot.png'), dpi=400)
plt.show()
